# %% [markdown]
# # PLACEHOLDER: Topic Title
#
# **Chapter N · Part PLACEHOLDER** &nbsp;|&nbsp; *Data Science: An Interactive Textbook*
#
# ---
#
# ## Learning Objectives
#
# By the end of this notebook you will be able to:
#
# - [ ] PLACEHOLDER: Objective 1 — a skill you can demonstrate in code
# - [ ] PLACEHOLDER: Objective 2 — a concept you can explain and implement
# - [ ] PLACEHOLDER: Objective 3 — a model or transform you can build from scratch
# - [ ] PLACEHOLDER: Objective 4 — a decision you can make and justify
#
# **Estimated time:** 45–60 minutes &nbsp;|&nbsp;
# **Prerequisites:** [Chapter N-1](../NN_prev/index.md)

# %% [markdown]
# ## Agenda
#
# 1. [Setup](#1-setup) — imports and data
# 2. [Motivation](#2-motivation) — the problem we're solving
# 3. [Core Concept](#3-core-concept) — theory in one screen
# 4. [Implementation from Scratch](#4-implementation-from-scratch)
# 5. [Using the Library](#5-using-the-library)
# 6. [Visualization & Interpretation](#6-visualization--interpretation)
# 7. [Experiments](#7-experiments) — what happens when we change things?
# 8. [Exercises](#8-exercises)
# 9. [Summary](#9-summary)

# %% [markdown]
# ## 1. Setup
#
# Run this cell first — it imports libraries and loads the data for this notebook.

# %%
# ── Standard imports ──────────────────────────────────────
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# PLACEHOLDER: Add topic-specific imports below
# from sklearn.PLACEHOLDER import PLACEHOLDER

# ── Plot aesthetics ───────────────────────────────────────
mpl.rcParams.update({
    'figure.figsize':   (9, 5),
    'figure.dpi':       120,
    'axes.spines.top':  False,
    'axes.spines.right':False,
    'axes.grid':        True,
    'grid.alpha':       0.3,
    'font.size':        12,
})
sns.set_theme(style='whitegrid', palette='muted')

# ── Reproducibility ───────────────────────────────────────
SEED = 42
np.random.seed(SEED)

print('Setup complete.')

# %% [markdown]
# ### 1.1 Dataset
#
# **PLACEHOLDER: Dataset name** — PLACEHOLDER: one-sentence description.
#
# | Field | Value |
# |-------|-------|
# | Source | PLACEHOLDER |
# | Rows | PLACEHOLDER |
# | Columns | PLACEHOLDER |
# | Task | PLACEHOLDER |

# %%
# PLACEHOLDER: Load or generate the dataset
# Option A — real dataset:
#   df = pd.read_csv('https://PLACEHOLDER/dataset.csv')
#
# Option B — synthetic:
#   from sklearn.datasets import make_PLACEHOLDER
#   X, y = make_PLACEHOLDER(n_samples=500, random_state=SEED)
#   df = pd.DataFrame(X, columns=[f'x{i}' for i in range(X.shape[1])])
#   df['target'] = y

# Show first rows
# df.head()

# %%
# Quick sanity check — shape, dtypes, nulls
# print(df.shape)
# df.info()
# df.describe()

# %% [markdown]
# ## 2. Motivation
#
# PLACEHOLDER: Frame the problem. What breaks without this technique? Start from something familiar.
#
# > **PLACEHOLDER: The core question this notebook answers.**

# %%
# PLACEHOLDER: Short demo showing WHY this topic matters.
# Ideal structure: show a failure / naive approach first, then hint at the solution.

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# Left: naive/broken approach
axes[0].set_title('PLACEHOLDER: Without this technique')

# Right: with the technique
axes[1].set_title('PLACEHOLDER: With this technique')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Core Concept
#
# PLACEHOLDER: Concise theory. Keep this cell to one screen during a slide presentation.
#
# **Formal definition:**
#
# $$
# \text{PLACEHOLDER: key equation}
# $$
#
# **Key terms:**
# - $\text{PLACEHOLDER}$ — PLACEHOLDER definition
# - $\text{PLACEHOLDER}$ — PLACEHOLDER definition
#
# **Intuition:** PLACEHOLDER: one-sentence plain-language summary.

# %% [markdown]
# ### 3.1 Visual Intuition
#
# PLACEHOLDER: Replace this placeholder figure with a diagram that builds intuition.
#
# ```{figure} ../path/to/figure.png
# :width: 70%
# :align: center
# PLACEHOLDER: Caption explaining the diagram.
# ```

# %% [markdown]
# ## 4. Implementation from Scratch
#
# Before using the library, implement the core algorithm step by step.
#
# Understanding the mechanics prevents black-box thinking.

# %%
def placeholder_algorithm(X, **kwargs):
    """
    PLACEHOLDER: Brief description of what this does.

    Parameters
    ----------
    X : array-like of shape (n_samples, n_features)
        PLACEHOLDER description

    Returns
    -------
    result : PLACEHOLDER type
        PLACEHOLDER description
    """
    # Step 1: PLACEHOLDER
    pass

    # Step 2: PLACEHOLDER
    pass

    # Step 3: PLACEHOLDER
    return None

# %%
# Test your from-scratch implementation
# X_test = np.array([[...], [...]])
# result = placeholder_algorithm(X_test)
# print('From scratch:', result)

# %% [markdown]
# ## 5. Using the Library
#
# Now apply the production implementation from scikit-learn (or equivalent).
# Compare to your scratch implementation — results should match.

# %%
# PLACEHOLDER: Import and instantiate the model
# from sklearn.PLACEHOLDER import PLACEHOLDER
#
# model = PLACEHOLDER(
#     PLACEHOLDER_param1=PLACEHOLDER_value,
#     PLACEHOLDER_param2=PLACEHOLDER_value,
#     random_state=SEED,
# )

# Fit
# model.fit(X_train, y_train)   # or just X_train for unsupervised

# Predict / transform
# y_pred = model.predict(X_test)

# Inspect
# print('Library result:', y_pred[:5])

# %%
# Compare from-scratch vs library results
# np.testing.assert_allclose(scratch_result, library_result, rtol=1e-5)
# print('Results match!')

# %% [markdown]
# ## 6. Visualization & Interpretation
#
# PLACEHOLDER: Explain what the plots below show and what to look for.

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# ── Plot 1 ────────────────────────────────────────────────
ax = axes[0]
# PLACEHOLDER: Primary visualization
# e.g., decision boundary, residuals, cluster assignments
ax.set_title('PLACEHOLDER: Plot 1 title')
ax.set_xlabel('PLACEHOLDER')
ax.set_ylabel('PLACEHOLDER')

# ── Plot 2 ────────────────────────────────────────────────
ax = axes[1]
# PLACEHOLDER: Secondary visualization
# e.g., learning curve, feature importance, confusion matrix
ax.set_title('PLACEHOLDER: Plot 2 title')

plt.suptitle('PLACEHOLDER: Overall figure title', fontsize=14, y=1.02)
plt.tight_layout()
plt.show()

# %%
# PLACEHOLDER: Optional interactive visualization with plotly or ipywidgets
# import plotly.express as px
# fig = px.scatter(df, x='PLACEHOLDER', y='PLACEHOLDER', color='PLACEHOLDER',
#                  title='PLACEHOLDER')
# fig.show()

# %% [markdown]
# ## 7. Experiments
#
# **What happens when we change key parameters?**
#
# Modify the values below and re-run to build intuition.

# %%
# ── Parameter sweep ───────────────────────────────────────
param_values = [PLACEHOLDER_1, PLACEHOLDER_2, PLACEHOLDER_3, PLACEHOLDER_4]
results = []

for val in param_values:
    # PLACEHOLDER: fit model with val as the parameter
    # PLACEHOLDER: record a metric (e.g. accuracy, inertia, MSE)
    metric = None  # PLACEHOLDER
    results.append({'param': val, 'metric': metric})

results_df = pd.DataFrame(results)

# Plot
fig, ax = plt.subplots(figsize=(7, 4))
ax.plot(results_df['param'], results_df['metric'], marker='o')
ax.set_xlabel('PLACEHOLDER parameter')
ax.set_ylabel('PLACEHOLDER metric')
ax.set_title('Effect of PLACEHOLDER parameter on PLACEHOLDER metric')
plt.show()

# %% [markdown]
# ## 8. Exercises
#
# Complete these exercises in order. Each builds on the previous.
#
# ---
#
# ### Exercise 1 — Direct Application *(★☆☆)*
#
# PLACEHOLDER: A concrete task that directly applies the notebook content.
#
# **Task:** PLACEHOLDER
#
# **Expected output:** PLACEHOLDER

# %%
# ── Exercise 1 Workspace ──────────────────────────────────
# Your code here

# %%
# ── Solution: Exercise 1 ──────────────────────────────────
# PLACEHOLDER: Solution code

# Explanation:
# PLACEHOLDER: Step-by-step explanation of the solution

# %% [markdown]
# ### Exercise 2 — Extend & Compare *(★★☆)*
#
# PLACEHOLDER: An exercise requiring synthesis with prior chapters.
#
# **Task:** PLACEHOLDER
#
# **Hint:** PLACEHOLDER — what prior concept does this build on?

# %%
# ── Exercise 2 Workspace ──────────────────────────────────
# Your code here

# %%
# ── Solution: Exercise 2 ──────────────────────────────────
# PLACEHOLDER: Solution code

# %% [markdown]
# ### Exercise 3 — Open Challenge *(★★★)*
#
# PLACEHOLDER: An open-ended or real-dataset challenge.
#
# **Task:** PLACEHOLDER
#
# *No single right answer — document your reasoning.*

# %%
# ── Exercise 3 Workspace ──────────────────────────────────
# Your code here

# %% [markdown]
# ## 9. Summary
#
# | Concept | Key Takeaway |
# |---|---|
# | PLACEHOLDER concept 1 | PLACEHOLDER takeaway |
# | PLACEHOLDER concept 2 | PLACEHOLDER takeaway |
# | PLACEHOLDER concept 3 | PLACEHOLDER takeaway |
# | When to use | PLACEHOLDER |
# | Common pitfall | PLACEHOLDER |
#
# ---
#
# **Next:** [PLACEHOLDER: Next Topic](./NN_next_topic.ipynb) — PLACEHOLDER: one sentence on what comes next and why.
#
# **Review:** If anything was unclear, re-read [PLACEHOLDER: reading companion](./NN_reading.md) before continuing.

# %% [markdown]
# ## Resources
#
# | Resource | Why it's useful |
# |---|---|
# | PLACEHOLDER: textbook / paper | PLACEHOLDER |
# | [scikit-learn docs: PLACEHOLDER](https://scikit-learn.org/stable/) | Official API reference |
# | PLACEHOLDER: blog post or tutorial | PLACEHOLDER |
#
# ---
#
# *Data Science: An Interactive Textbook* &nbsp;·&nbsp; Chapter N &nbsp;·&nbsp; PLACEHOLDER: Topic
